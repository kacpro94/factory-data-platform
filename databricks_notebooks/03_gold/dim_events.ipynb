# %%
# %sql
CREATE OR REPLACE TABLE data_warehouse_factory.gold.dim_events AS
SELECT * FROM VALUES
  (1, '11-Swap role',            'Role Swap',        TRUE,  TRUE,  TRUE,  FALSE, 'Przeniesienie na inną komórkę/rolę'),
  (2, 'Swap role',               'Role Swap',        TRUE,  TRUE,  TRUE,  FALSE, 'Przeniesienie na inną komórkę/rolę'),
  (3, '62-Absence',              'Absence',          FALSE, TRUE,  FALSE, TRUE,  'Nieobecność / L4 / urlop'),
  (4, 'Absence',                 'Absence',          FALSE, TRUE,  FALSE, TRUE,  'Nieobecność / L4 / urlop'),
  (5, 'Zmiana oprzyrządowania',  'Setup / Tooling',  TRUE,  FALSE, FALSE, FALSE, 'Przezbrojenie maszyny na linii'),
  (6, 'Awaria',                  'Downtime',         FALSE, FALSE, FALSE, FALSE, 'Postój nieplanowany / awaria techniczna'),
  (7, 'Przerwa',                 'Break',            FALSE, FALSE, FALSE, FALSE, 'Przerwa regeneracyjna / regulaminowa'),
  (8, 'Szkolenie',               'Training',         TRUE,  FALSE, FALSE, FALSE, 'Podnoszenie kwalifikacji / onboarding'),
  (9, 'Inne',                    'Other',            TRUE,  FALSE, FALSE, FALSE, 'Inne czynności operacyjne')
AS t(event_type_key, event_type_name, event_category, is_utilized_time, affects_default_assignment, is_swap, is_absence, description);
