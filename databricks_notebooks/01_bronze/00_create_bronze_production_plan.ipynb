# %%
# %sql
CREATE TABLE IF NOT EXISTS data_warehouse_factory.bronze.bronze_production_plan (
  record_type STRING,
  line_code STRING,
  line_name STRING,
  assigned_cells ARRAY<STRUCT<cell_code: STRING, cell_name: STRING>>,
  start_datetime STRING,
  end_datetime STRING,
  plan_status STRING,
  planned_capacity_pct INT,
  remarks STRING,
  ingested_at STRING,
  source STRING,
  _source_file STRING,
  _ingested_at TIMESTAMP
);
