# %%
# %sql
CREATE TABLE IF NOT EXISTS data_warehouse_factory.bronze.bronze_employee_assignments (
  line_code STRING,
  line_name STRING,
  cell_code STRING,
  cell_name STRING,
  default_employee_key INT,
  default_employee_name STRING,
  backup_employee_key INT,
  backup_employee_name STRING,
  valid_from STRING,
  shift STRING,
  remarks STRING,
  ingested_at STRING,
  source STRING,
  _source_file STRING,
  _ingested_at TIMESTAMP
)
USING DELTA
