# %%
# %sql
CREATE TABLE IF NOT EXISTS data_warehouse_factory.bronze.bronze_production_structure (
  record_type STRING,      -- 'PRODUCTION_LINE' lub 'PRODUCTION_CELL'
  line_code STRING,        -- Kod linii (np. A01)
  line_name STRING,        -- Nazwa linii (NULL dla komórek)
  cell_code STRING,        -- Kod komórki (NULL dla linii)
  cell_name STRING,        -- Nazwa komórki (NULL dla linii)
  ingested_at STRING,      -- Data wygenerowania z aplikacji
  _source_file STRING,     -- Ścieżka do pliku JSON
  _ingested_at TIMESTAMP   -- Czas wczytania do Bronze
);
