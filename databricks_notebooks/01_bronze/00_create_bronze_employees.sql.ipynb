# %%
# %sql
CREATE OR REPLACE TABLE data_warehouse_factory.bronze.bronze_employees (
  employee_full_name STRING,
  work_center STRING,
  date_of_employment STRING,
  date_of_leaving STRING,
  ingested_at STRING,
  _source_file STRING,
  _ingested_at TIMESTAMP
);
