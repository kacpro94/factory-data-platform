# %%
# %sql
CREATE OR REPLACE TABLE data_warehouse_factory.bronze.bronze_events (
  employee_key INT,
  employee_full_name STRING,
  event_type STRING,
  swap_cell STRING,
  start_datetime STRING,
  end_datetime STRING,
  fte DOUBLE,
  remarks STRING,
  ingested_at STRING,
  source STRING,
  _source_file STRING,
  _ingested_at TIMESTAMP
);
